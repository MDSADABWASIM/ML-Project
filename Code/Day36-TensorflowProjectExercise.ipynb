# %% [markdown]
# # Tensorflow Project Exercise
# Let's wrap up this Deep Learning by taking a quick look at the effectiveness of Neural Nets!
#
# We'll use the [Bank Authentication Data Set](https://archive.ics.uci.edu/ml/datasets/banknote+authentication) from the UCI repository.
#
# The data consists of 5 columns:
#
# * variance of Wavelet Transformed image (continuous)
# * skewness of Wavelet Transformed image (continuous)
# * curtosis of Wavelet Transformed image (continuous)
# * entropy of image (continuous)
# * class (integer)
#
# Where class indicates whether or not a Bank Note was authentic.
#
# This sort of task is perfectly suited for Neural Networks and Deep Learning! Just follow the instructions below to get started!

# %% [markdown]
# ## Get the Data
#
# ** Use pandas to read in the bank_note_data.csv file **

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets/bank_note_data.csv')

# %% [markdown]
# ** Check the head of the Data **

# %%
df.head()
# Out:
#    Image.Var  Image.Skew  Image.Curt  Entropy  Class
# 0    3.62160      8.6661     -2.8073 -0.44699      0
# 1    4.54590      8.1674     -2.4586 -1.46210      0
# 2    3.86600     -2.6383      1.9242  0.10645      0
# 3    3.45660      9.5228     -4.0112 -3.59440      0
# 4    0.32924     -4.4552      4.5718 -0.98880      0

# %% [markdown]
# ## EDA
#
# We'll just do a few quick plots of the data.
#
# ** Import seaborn and set matplolib inline for viewing **

# %% [markdown]
# ** Create a Countplot of the Classes (Authentic 1 vs Fake 0) **

# %%
sns.countplot(x='Class',data=df)

# %% [markdown]
# ** Create a PairPlot of the Data with Seaborn, set Hue to Class **

# %%
sns.pairplot(df,hue='Class',diag_kind='hist')

# %% [markdown]
# ## Data Preparation
#
# When using Neural Network and Deep Learning based systems, it is usually a good idea to Standardize your data, this step isn't actually necessary for our particular data set, but let's run through it for practice!
#
# ### Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Create a StandardScaler() object called scaler.**

# %%
scaler = StandardScaler()

# %% [markdown]
# **Fit scaler to the features.**

# %%
scaler.fit(df.drop('Class',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# **Use the .transform() method to transform the features to a scaled version.**

# %%
scaled_feat = scaler.fit_transform(df.drop('Class',axis=1))

# %% [markdown]
# **Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.**

# %%
scaled_df = pd.DataFrame(scaled_feat,columns=df.columns[:-1])

# %%
scaled_df.head()
# Out:
#    Image.Var  Image.Skew  Image.Curt   Entropy
# 0   1.121806    1.149455   -0.975970  0.354561
# 1   1.447066    1.064453   -0.895036 -0.128767
# 2   1.207810   -0.777352    0.122218  0.618073
# 3   1.063742    1.295478   -1.255397 -1.144029
# 4  -0.036772   -1.087038    0.736730  0.096587

# %% [markdown]
# ## Train Test Split
#
# ** Create two objects X and y which are the scaled feature values and labels respectively.**

# %%
from sklearn.model_selection import train_test_split

# %%
 X = scaled_df
 y = df['Class']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1367    1
# 1368    1
# 1369    1
# 1370    1
# 1371    1
# Name: Class, Length: 1372, dtype: int64

# %% [markdown]
# ** Use SciKit Learn to create training and testing sets of the data as we've done in previous lectures:**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Tensorflow

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %% [markdown]
# ** Create a list of feature column objects using tf.feature_column.numeric_column()**

# %%
scaled_df.columns
# Out:
# Index(['Image.Var', 'Image.Skew', 'Image.Curt', 'Entropy'], dtype='object')

# %%
# Changing name of columns to without spaces is also important in tensorflow
image_var = tf.feature_column.numeric_column("Image.Var")
image_skew = tf.feature_column.numeric_column('Image.Skew')
image_curt = tf.feature_column.numeric_column('Image.Curt')
entropy =tf.feature_column.numeric_column('Entropy')

# %%
feat_cols = [image_var,image_skew,image_curt,entropy]

# %% [markdown]
# ** Create an object called classifier which is a DNNClassifier from learn. Set it to have 2 classes and a [10,20,10] hidden unit layer structure:**

# %%
classifier = tf.estimator.DNNClassifier(hidden_units=[10, 20, 10], n_classes=2,feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/4c/fs268wds377cf2j6hw31lp2c0000gp/T/tmpno8wqj1g
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/4c/fs268wds377cf2j6hw31lp2c0000gp/T/tmpno8wqj1g', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %% [markdown]
# ** Now create a tf.estimator.inputs.pandas_input_fn that takes in your X_train, y_train, batch_size and set shuffle=True. You can play around with the batch_size parameter if you want, but let's start by setting it to 20 since our data isn't very big. **

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=20,shuffle=True)

# %% [markdown]
# ** Now train classifier to the input function. Use steps=500. You can play around with these values if you want!**
#
# *Note: Ignore any warnings you get, they won't effect your output*

# %%
classifier.train(input_fn=input_func,steps=500)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/4c/fs268wds377cf2j6hw31lp2c0000gp/T/tmpno8wqj1g/model.ckpt.
# INFO:tensorflow:loss = 16.3387, step = 1
# INFO:tensorflow:Saving checkpoints for 48 into /var/folders/4c/fs268wds377cf2j6hw31lp2c0000gp/T/tmpno8wqj1g/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13895527.

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ** Create another pandas_input_fn that takes in the X_test data for x. Remember this one won't need any y_test info since we will be using this for the network to create its own predictions. Set shuffle=False since we don't need to shuffle for predictions.**

# %%
pred_func = tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=len(X_test),shuffle=False)

# %% [markdown]
# ** Use the predict method from the classifier model to create predictions from X_test **

# %%
prediction = list(classifier.predict(input_fn=pred_func))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/4c/fs268wds377cf2j6hw31lp2c0000gp/T/tmpno8wqj1g/model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
prediction[0]
# Out:
# {'logits': array([-6.1949444], dtype=float32),
#  'logistic': array([0.00203556], dtype=float32),
#  'probabilities': array([0.9979645 , 0.00203556], dtype=float32),
#  'class_ids': array([0]),
#  'classes': array([b'0'], dtype=object),
#  'all_class_ids': array([0, 1], dtype=int32),
#  'all_classes': array([b'0', b'1'], dtype=object)}

# %%
final_pred = []
for pred in prediction:
    final_pred.append(pred['class_ids'][0])

# %% [markdown]
# ** Now create a classification report and a Confusion Matrix. Does anything stand out to you?**

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print('** CONFUSION MATRIX **')
confusion_matrix(y_test,final_pred)
# Out:
# ** CONFUSION MATRIX **
# array([[232,   6],
#        [  0, 174]])

# %%
print(classification_report(y_test,final_pred))
# Out:
# precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       238
#            1       0.97      1.00      0.98       174
#
#     accuracy                           0.99       412
#    macro avg       0.98      0.99      0.99       412
# weighted avg       0.99      0.99      0.99       412

# %% [markdown]
# ## Optional Comparison
#
# ** You should have noticed extremely accurate results from the DNN model. Let's compare this to a Random Forest Classifier for a reality check!**
#
# **Use SciKit Learn to Create a Random Forest Classifier and compare the confusion matrix and classification report to the DNN model**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=200)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model_pred = model.predict(X_test)

# %%
print(confusion_matrix(y_test,model_pred))
# Out:
# [[235   3]
#  [  1 173]]

# %%
print(classification_report(y_test,model_pred))
# Out:
# precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       238
#            1       0.98      0.99      0.99       174
#
#     accuracy                           0.99       412
#    macro avg       0.99      0.99      0.99       412
# weighted avg       0.99      0.99      0.99       412

# %% [markdown]
# ** It should have also done very well, possibly perfect! Hopefully you have seen the power of DNN! **

# %% [markdown]
# # Great Job!
